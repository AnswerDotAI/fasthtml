# %% [markdown]
# ## Full Example #1 - ToDo App
#
# The canonical demo web app! A TODO list. We've made multiple versions - so in addition to this minimal example you check out [this](https://github.com/AnswerDotAI/fasthtml-tut) series with increasing complexity from Jeremy's talk (link when available) and the example linked from the homepage [here](https://github.com/AnswerDotAI/fasthtml-example/tree/main/01_todo_app).
#
# ::: {.callout-note}
# In fact, let's not add another version to the mix! This example will be replaced soon, for now you can check out the ones linked above.
# :::

# %% [markdown]
# ![image.png](attachment:image.png)
